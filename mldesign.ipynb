# %%
# 配置环境 在已有pytorch的基础上还需要安装两个包
#打印进度条
# %pip install progressbar2 
#用于记录log
# %pip install fitlog 
# %fitlog init

# %% [markdown]
# ### 任务书部分

# %%
### pic2pic
# !python "my_train.py" --model_name pic2pic --ep 210 --dropout 1
### GAN实现
# !python "my_train.py" --model_name GAN --ep 210 --dropout 0
### AutoEncoder 实现
# !python "my_train.py" --model_name AutoEncoderGen --ep 210 --dropout 1

# %% [markdown]
# ### 优化模型

# %%
# 最优cGAN
# !python "my_train.py" --model_name ResGAN --ep 210 --lrG 0.001000 --lrD 0.000005 --dg_rate 2 --dp_epoch 10 --weight_pic 50 --dropout 0 --n_block 22

# 最优单生成器
# !python "my_train.py" --model_name ResGen --ep 209 --lrG 0.000500 --bs 4 --n_block 34

# pix2pix改良版
# !python "my_train.py" --model_name pic2pic --ep 210 --lrG 0.002000 --lrD 0.000005 --bs 8 --dg_rate 2 --dp_epoch 10 --weight_pic 20 --add_res '13463'
